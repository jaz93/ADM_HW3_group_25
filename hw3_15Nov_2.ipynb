# %%
import csv
import pandas as pd
#import numpy as np
import nltk 
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk import word_tokenize
import string
from nltk.tokenize import RegexpTokenizer
from itertools import chain
import json

# %%
df = pd.read_csv("/Users/milpro/Desktop/Universita/ADM_Aris/HW3/Airbnb_Texas_Rentals.csv")
df = df.replace(r'\\n', " ", regex = True)
df1 = df.values.tolist()

for row in df1:
    with open("/Users/milpro/Desktop/Universita/ADM_Aris/HW3/doc_tsv/doc_" +str(df1.index(row))+ ".tsv", 'w', newline='',encoding='utf8') as f_output:
        tsv_output = csv.writer(f_output, delimiter='\t',)
        tsv_output.writerow(row[1:])

# %%
len(df)
# Out:
# 18259

# %%
len(df1)
# Out:
# 9129

# %%
df1
# Out:
# [[1,
#   '$27',
#   '2',
#   'Humble',
#   'May 2016',
#   'Welcome to stay in private room with queen bed and detached private bathroom on the second floor. Another private bedroom with sofa bed is available for additional guests. 10$ for an additional guest. 10min from IAH airport Airport pick-up/drop off is available for $10/trip.',
#   30.0201379199512,
#   -95.29399600425128,
#   '2 Private rooms/bathroom 10min from IAH airport',
#   'https://www.airbnb.com/rooms/18520444?location=Cleveland%2C%20TX'],
#  [2,
#   '$149',
#   '4',
#   'San Antonio',
#   'November 2010',
#   'Stylish, fully remodeled home in upscale NW – Alamo Heights Area.   Amazing location - House conveniently located in quiet street, with beautiful seasoned trees, prestigious neighborhood and very close to the airport, 281, 410 loop and down-town area.   Featuring an open floor plan, original hardwood floors, 3 bedrooms, 3 FULL bathrooms + an independent garden-TV room which can sleep 2 more  European inspired kitchen and “top of the line” decor. Driveway can park 4 cars.',
#   29.503067675606104,
#   -98.4476879378504,
#   'Unique Location! Alamo Heights - Designer Inspired',
#   'https://www.airbnb.com/rooms/17481455?location=Cibolo%2C%20TX'],
#  [3,
#   '$59',
#   '1',
#   'Houston',
#   'January 2017',
#   "'River house on island close to the city'  A well maintained river house off the San Jacinto river with extra room for temporary visitors.",
#   29.829352227214898,
#   -95.0815494887563,
#   'River house near the city',
#   'https://www.airbnb.com/rooms/16926307?location=Beach%20City%2C%20TX'],
#  [4,
#   '$60',
#   '1',
#   'Bryan',
#   'February 2016',
#   'Private bedroom in a cute little home situated in the coveted Garden Acres neighborhood in Bryan. The bedroom has its own private access and its own private bathroom.',
#   30.6373042787676,
#   -96.33784597296308,
#   'Private Room Close to Campus',
#   'https://www.airbnb.com/rooms/11839729?location=College%20Station%2C%20TX'],
#  [5,
#   '$75',
#   '2',
#   'Fort Worth',
#   'February 2017',
#   "Welcome to our original 1920's home. We recently purchased this 1922 home just a mile outside of downtown Fort Worth and have been happy restoring the original character that the home was built with. You're just a 5 minute drive from all that downtown has to offer and just across the street from the currently being rejuvenated Gateway Park.",
#   32.7470973543511,
#   -97.2864343970125,
#   'The Porch',
#   'https://www.airbnb.com/rooms/17325114?location=Colleyville%2C%20TX'],
#  [6,
#   '$250',
#   '4',
#   'Conroe',
#   'August 2016',
#   'My place is close to Lake Conroe, family-friendly activities, nightlife. You’ll love my place because of the outdoors space and the neighborhood. My place is good for couples, solo adventurers, business travelers, families (with kids), and big groups.',
#   30.370455202614004,
#   -95.38531903586781,
#   'Gorgeous Home with Country Setting',
#   'https://www.airbnb.com/rooms/14466133?location=Cleveland%2C%20TX'],
#  [7,
#   '$129',
#   '3',
#   'Cedar Creek',
#   'March 2016',
#   'Rustic country retreat on 8 acres southeast of Austin. Converted modular home with all the amenities needed while offering a Texas experiences. Less than 15 miles to Austin airport, Circuit of the Americas (COTA) or Formula One. Trailer parking avail',
#   30.109838308143,
#   -97.47341691286819,
#   'Cozy and Quaint Country Retreat with Acreage.',
#   'https://www.airbnb.com/rooms/12491762?location=Cedar%20Creek%2C%20TX'],
#  [8,
#   '$25',
#   '1',
#   'Fort Worth',
#   'January 2016',
#   'This is a beautiful bedroom with a queen size bed and closet. We do not have pets and the house is always clean. The bathroom is shared and supplies such as towels and shampoo are available. We are only some miles from Downtown, TCU, TCC, and Stockyards.',
#   32.6896114095237,
#   -97.29816086056499,
#   'Friendly Private Room in َQuiet Neighborhood',
#   'https://www.airbnb.com/rooms/18977363?location=Cleburne%2C%20TX'],
#  [9,
#   '$345',
#   '3',
#   'Rockport',
#   'February 2016',
#   'First class and comfortable condo with the bests views from bottom deck and master bedroom patio.\\r Pier is just a few steps away from your patio.',
#   28.1037257224157,
#   -97.025832094037,
#   '608 - Bayfront Condos',
#   'https://www.airbnb.com/rooms/17559848?location=Bayside%2C%20TX'],
#  [10,
#   '$72',
#   'Studio',
#   'San Antonio',
#   'August 2013',
#   'Private entrance to your own \\',
#   29.480646154747895,
#   -98.4956917207437,
#   'Cozy Historic Private Studio',
#   'https://www.airbnb.com/rooms/1588127?location=Colorado%20River%2C%20TX'],
#  [11,
#   '$65',
#   '1',
#   'Irving',
#   'July 2015',
#   'My cool and comfortable bedroom apartment feels like home. It comfortably fits 2 people and centrally located on a quiet street. Enjoy a gourmet kitchen and easy access to all major highways.',
#   32.8621160084978,
#   -97.0026429124416,
#   'Cozy 1 bedroom/bathroom with pool',
#   'https://www.airbnb.com/rooms/7276294?location=Colleyville%2C%20TX'],
#  [12,
#   '$116',
#   '1',
#   'Euless',
#   'September 2014',
#   'Gated Estate in the heart of the DFW metro. Sets on 2.5 wooded acres. Home overlooks a beautiful pond. 8 -10 mins to DFW Airport and 25-35 mins to Love Field Airport. Located minutes away from Dallas &amp; Fort Worth, American Airlines Center, Dallas museums, Deep Elum, AT&amp;T Stadium, Global Life Park, Six Flags, Fort Worth Stock Yards, Texas Motor Speed Way, Grapevine Mills Mall, Gaylord Texan, Great Wolf Lodge, Check out our other listing we have at our home - FABEULESS HIDEAWAY',
#   32.865348324183195,
#   -97.0810343348168,
#   'Quiet Cozy Room',
#   'https://www.airbnb.com/rooms/4251773?location=Colleyville%2C%20TX'],
#  [13,
#   '$160',
#   '2',
#   'Round Mountain',
#   'August 2012',
#   "Our place combines the convenience for visiting the Austin area, while also being far from the maddening crowd. It's very peaceful and quiet here, with views to die for. Nature in spades is what we have to offer. Humming birds galore! Come see.",
#   30.3520048470848,
#   -98.14624215486799,
#   'Cypress Creek Retreat Hamilton Pool',
#   'https://www.airbnb.com/rooms/658762?location=Colorado%20River%2C%20TX'],
#  [14,
#   '$110',
#   '1',
#   'San Antonio',
#   'June 2017',
#   'This home is on the North Side of San Antonio, 3 minutes away from a great golfing course and a JW Marriott Resort and Spa. This is a great stopping place for a family and comes with all amenities from cable, internet to a laundry room and 2 bathrooms. This house is against a green belt so you can enjoy the back yard and nature.This area is safe and my neighbors are also great! Hope you enjoy your stay and more so enjoy San Antonio!',
#   29.6690314042162,
#   -98.4183517679751,
#   'A Cozy Home with a Beautiful Nature Views',
#   'https://www.airbnb.com/rooms/19190311?location=Cibolo%2C%20TX'],
#  [15,
#   '$175',
#   '2',
#   'Kerrville',
#   'August 2016',
#   "My place is close to downtown Kerrville. Beautiful pine ceilings and cozy fireplace. Cottage appeal in a unique and eclectic Kerrville neighborhood! Comes with screened porch and huge backyard. Washer dryer available also for guest's convenience. Great place to use as a home base for exploring Texas wine country nearby. I have a covered carport with 2 parking spaces included in the rental price-which is great to have if we get rain or bad weather, your car is protexted.",
#   30.0736670299709,
#   -99.1613652179931,
#   'Cozy cottage charm,right in Kerrville!',
#   'https://www.airbnb.com/rooms/14694333?location=Center%20Point%2C%20TX'],
#  [16,
#   '$88',
#   '2',
#   'New Braunfels',
#   'April 2017',
#   'This is new house with a hint of Texas Country Chic.',
#   29.642810974823103,
#   -98.1144006594656,
#   '2 bedrooms 1.5 bath in a great location.',
#   'https://www.airbnb.com/rooms/18683743?location=Canyon%20Lake%2C%20TX'],
#  [17,
#   '$82',
#   '2',
#   'Austin',
#   'December 2015',
#   'Cute two bedroom with lots of windows, sunny back deck, front porch in friendly neighborhood (Hyde Park, Austin) near UT and downtown. Easy walk to coffee shops and restaurants!',
#   30.3095220042058,
#   -97.73171047109501,
#   'Cosy 2 Bedroom in Hyde Park!',
#   'https://www.airbnb.com/rooms/18550276?location=Cedar%20Park%2C%20TX'],
#  [18,
#   '$275',
#   '1',
#   'Port Aransas',
#   'February 2017',
#   'My place is close to the beach, restaurants and dining, family-friendly activities, and great views. My place is good for couples, solo adventurers, and business travelers.',
#   27.8171755178407,
#   -97.0680901451661,
#   'Ocean Getaway with Magnificent Views',
#   'https://www.airbnb.com/rooms/17402254?location=Corpus%20Christi%2C%20TX'],
#  [19,
#   '$1500',
#   '4',
#   'Houston',
#   'January 2017',
#   '4 bedroom 2 bathroom home with an open floor plan great for entertaining located in a quiet neighborhood and conveniently located to 59 and beltway 8.',
#   29.954680087782503,
#   -95.1760702862707,
#   'Super Bowl 2017 4 BDRM Home Retreat',
#   'https://www.airbnb.com/rooms/16964526?location=Channelview%2C%20TX'],
#  [20,
#   '$250',
#   '2',
#   'Frisco',
#   'December 2014',
#   'This unique lakefront area is perfect for creating wonderful memories with your friends and family. It is located right outside the City of Frisco, so it is less than 5 minutes to any shopping and entertainment, yet it is a cozy relaxed atmosphere.',
#   33.1557762184237,
#   -96.9304385019675,
#   'Lake Lewisville Lakefront Convenient to Frisco',
#   'https://www.airbnb.com/rooms/4785810?location=Corinth%2C%20TX'],
#  [21,
#   '$2999',
#   '4',
#   'Katy',
#   'January 2017',
#   '4 Bedroom 3 Baths Sleeps 10-12 Theater Room Plus Luxury Car',
#   29.8238021572358,
#   -95.7306365899502,
#   'New Super Bowl House & Luxury Car',
#   'https://www.airbnb.com/rooms/17005150?location=Cinco%20Ranch%2C%20TX'],
#  [22,
#   '$350',
#   '3',
#   'College Station',
#   'September 2015',
#   'Nice 3 bed, 2 bathroom home in the beautiful Castlegate neighborhood. 50 inch flat screen in the living room and main bedroom. Very clean home with ample room to host 5 people comfortably. I can set the ping pong table up in the garage if requested',
#   30.546703842584897,
#   -96.28285308541821,
#   '3/2 Home in Castlegate',
#   'https://www.airbnb.com/rooms/8419392?location=College%20Station%2C%20TX'],
#  [23,
#   '$165',
#   '3',
#   'Katy',
#   'September 2016',
#   'This apartment is very nice for any family or group for a relaxing time or just a place to stay. Everyone is welcome. You are welcomed to use the pool and workout equipment at your leisure. This home also offers a full size garage for parking of two vehicles.',
#   29.7665527064473,
#   -95.78319239378192,
#   'Getaway Gateway Apartment Home',
#   'https://www.airbnb.com/rooms/17188329?location=Cinco%20Ranch%2C%20TX'],
#  [24,
#   '$65',
#   '1',
#   'Katy',
#   'September 2016',
#   'My place is close to Katy Mills Mall Shopping, LaCentera Mall, Movie Theaters, Restaurants I Grand Parkway., nightlife. You’ll love my place because of the neighborhood , the comfy bed, the kitchen, the outdoors space, the light. My place is good for couples, business travelers, and families (with kids).',
#   29.740703522799603,
#   -95.82587851318192,
#   'Luxury Master Bedroom in Safe & Quite Neibourhood',
#   'https://www.airbnb.com/rooms/15860117?location=Cinco%20Ranch%2C%20TX'],
#  [25,
#   '$100',
#   'Studio',
#   'Denton',
#   'November 2015',
#   'A converted carriage house walking distance to downtown Denton and University of North Texas Campus. DCTA bus stop located across the street and downtown DCTA train station a mile away. Has a kitchenette with microwave, refrigerator with freezer, and a coffee pot. Has a Murphy bed downstairs, and a loft with space for an air mattress. Please use caution on ladder stairs.',
#   33.2161402649842,
#   -97.13775674563091,
#   'Historic Converted Carriage House',
#   'https://www.airbnb.com/rooms/16650025?location=Corinth%2C%20TX'],
#  [26,
#   nan,
#   '2',
#   'San Antonio',
#   'July 2014',
#   '2 bedroom 4 bed chalet/town-home sleeps 6-8 with 2 pools and hottub! central San Antonio Only 15-18 min river walk 20-25 min sea world 15 min fiesta Texas, 25 min Gruene/new braunfels. Onsite concierge medicine, Rental car, massage and babysitting available at discounted prices.',
#   nan,
#   nan,
#   'ChaletAzul 2RM/4BD 30day rent Avail',
#   'https://www.airbnb.com/rooms/6088158?location=Cibolo%2C%20TX'],
#  [27,
#   '$36',
#   '1',
#   'Richmond',
#   'February 2017',
#   "Private Room (shared bathroom) in a warm family home. It's perfect for business trips, vacation and extended stays. If you are in town as a childbirth tourist, this is also a perfect place for you.",
#   29.695526637473197,
#   -95.69011086442491,
#   'King Size Bed room',
#   'https://www.airbnb.com/rooms/17407499?location=Cinco%20Ranch%2C%20TX'],
#  [28,
#   '$65',
#   '1',
#   'Katy',
#   'January 2017',
#   'Cozy room, special for couples or business trips. We talk spanish, english and french',
#   29.7809173772544,
#   -95.7949451191589,
#   'Private Room in Katy',
#   'https://www.airbnb.com/rooms/16916119?location=Cinco%20Ranch%2C%20TX'],
#  [29,
#   '$110',
#   '1',
#   'Austin',
#   'September 2015',
#   'Comfortable Traditional Interior Furniture in Amazing Location minutes Drive to SoCo, Downtown, ACL, &amp; SXSW. Walk to SoLa Eateries Coffee or Bars! Large queen bed &amp; sofa double bed comfortably accommodates up to 4. Free WiFi, Cable TV &amp; 1 Reserved Parking.',
#   30.244296163892898,
#   -97.7744685806115,
#   'Fabulous Central Austin Condo!',
#   'https://www.airbnb.com/rooms/13571814?location=Austin%2C%20TX'],
#  [30,
#   '$650',
#   '1',
#   'Houston',
#   'July 2016',
#   'Upstairs &amp; down stairs 2 beds included, great for Super Bowl stay. Gated community serious inquiries only.',
#   29.793379870018395,
#   -95.1964005238801,
#   'Luxurious TH 10 min from Downtown',
#   'https://www.airbnb.com/rooms/16842438?location=Channelview%2C%20TX'],
#  [31,
#   '$194',
#   '3',
#   'Plano',
#   'August 2016',
#   'This beautiful home located in a nice and convenient community in North Plano with best schools around. You can stay here with a peaceful mind, because we have prepared everything brand new for you. You will find everything a hotel provide here, and much more! High speed wifi (ultimate fast speed up to 200 Mbps), 55 inch Smart TV(Netflix and local channels), double garage, outdoor grill, study area, etc. It is good for couples, business travellers, families (with kids), and big groups. BOOK NOW!',
#   33.0849532940703,
#   -96.78346949481121,
#   'Fully Renovated Vacation Home in North Plano',
#   'https://www.airbnb.com/rooms/15028039?location=Celina%2C%20TX'],
#  [32,
#   '$75',
#   '1',
#   'Houston',
#   'January 2017',
#   'This is a great space for couch surfing with lots of available space in the living room for up to 6 people. It is only 15 minute drive to the super bowl. A 15 min drive to downtown bars. A 10 min walk to the green line metro rail that goes downtown.',
#   29.729390998833104,
#   -95.31251441047571,
#   'Living Room for Super Bowl',
#   'https://www.airbnb.com/rooms/17009039?location=Channelview%2C%20TX'],
#  [33,
#   '$81',
#   'Studio',
#   'Arlington',
#   'September 2016',
#   'Our place is five to seven minutes directly north of AT&amp;T Stadium, and just as close to The Ballpark in Arlington, Six Flags, Hurricane Harbor, restaurants and dining, family-friendly activities, and nightlife. You’ll love our place because of the treed neighborhood near parks and trails, the comfy bed, and the outdoors space. Our place is good for couples, solo adventurers, and business travelers.',
#   32.770389542170804,
#   -97.0900119842005,
#   'Comfy Garage Apt + Pool Close to FUN!',
#   'https://www.airbnb.com/rooms/15190760?location=Bedford%2C%20TX'],
#  [34,
#   '$119',
#   '1',
#   'Austin',
#   'August 2010',
#   "Just minutes from Austin's main attractions, entire 400 sq ft attached apartment in desirable Tarrytown (1940s) neighborhood with living room, bedroom and bath. We are licensed by the City of Austin to operate a Short Term Rental. NOTE: 15% HOTEL OCCUPANCY TAX INCLUDED IN PRICE!",
#   30.300381938339,
#   -97.77885789311449,
#   'Sunny Central Austin Apartment',
#   'https://www.airbnb.com/rooms/46929?location=Colorado%20River%2C%20TX'],
#  [35,
#   '$225',
#   '4',
#   'Breckenridge',
#   'April 2016',
#   'The Bedroll Bunkhouse Ranch is nestled in on 30 acres of beautiful landscape. Very private setting. Come out with friends and family and enjoy our horse shoe pit, star gazzing, listen to the coyotes sing, or just sit and read a book.',
#   32.7999800551476,
#   -98.8443266414931,
#   'The stars at night are amazing',
#   'https://www.airbnb.com/rooms/18584603?location=Cisco%2C%20TX'],
#  [36,
#   '$88',
#   '1',
#   'Houston',
#   'August 2016',
#   "Come relax on the water in our beautiful beach house style river home. You'll love our shiplap walls but the view is even better!",
#   29.8262783359522,
#   -95.0782393406197,
#   'Monroe Manor',
#   'https://www.airbnb.com/rooms/19273801?location=Channelview%2C%20TX'],
#  [37,
#   '$85',
#   '1',
#   'Spicewood',
#   'December 2016',
#   'My place is close to  SXSW venues Poodies Roadhouse Pace Bend Park Pedernales River Marble Falls Texas Hill Country Apis Restaurant.   You’ll love my place because of the relaxing location, the pool, Canyon to hike in, Pedernales River to play in or launch your boat, the private park on the river, the people, the ambiance, the outdoors space, and the neighborhood. My place is good for couples, solo adventurers, and business travelers.  Dog and cats on property.',
#   30.387709501143497,
#   -98.09081262452308,
#   'Amethyst Room at Canyon Ranch',
#   'https://www.airbnb.com/rooms/17132740?location=Briarcliff%2C%20TX'],
#  [38,
#   '$105',
#   '1',
#   'Austin',
#   'January 2012',
#   'Modern remodeled Spartan on a large shaded lot.',
#   30.2775233800895,
#   -97.7191907633739,
#   'Chic 1953 Spartanette Guesthouse',
#   'https://www.airbnb.com/rooms/321636?location=Colorado%20River%2C%20TX'],
#  [39,
#   '$499',
#   '7',
#   'Fort Worth',
#   'April 2017',
#   'Sleeps 20 guests. Clean, cozy, laid back and quiet place. Plenty of space with property caretaker available at all times. Excellent for a big family group. Your safety and comfort is our main goal. Ample parking space for guests. This home is Wheel Chair accessible with 2 handicapped showers.',
#   32.6499464788143,
#   -97.4059861969121,
#   'Casa de Alexis Guesthome',
#   'https://www.airbnb.com/rooms/18366731?location=Cleburne%2C%20TX'],
#  [40,
#   '$25',
#   '1',
#   'Dallas',
#   'April 2016',
#   'LOW COST MOTEL STYLE PRIVATE ROOMS WITH DOOR LOCK &amp; KEY ! NO NEED TO SCHEDULE YOUR ARRIVAL AS WE MAY NOT BE HOME TO GREET YOU ! COME IN AND OUT ANYTIME AFTER 1PM ON YOUR DAY OF ARRIVAL !!!   24/7 KEYLESS ENTRY DOOR CODE, WIFI INFO, AND EVERYTHING YOU NEED TO KNOW ABOUT YOUR STAY WILL BE DETAILED IN AN EMAIL FROM AIRBNB ONCE RESERVATION CONFIRMED !  Plenty of free parking, 2 full Bathrooms 100% Hassle free and independent stay !  LOCATION: BICKERS ST. &amp; N WESTMORELAND RD. DALLAS 75212',
#   32.7866364570642,
#   -96.87466868796459,
#   '2. Available now, Private w-Key, TV-FREE Movies',
#   'https://www.airbnb.com/rooms/13568922?location=Carrollton%2C%20TX'],
#  [41,
#   '$35',
#   '1',
#   'Killeen',
#   'August 2016',
#   'My place is close to the airport and the city center.',
#   31.0883139608392,
#   -97.77755412368471,
#   'FEMALE GUEST ONLY',
#   'https://www.airbnb.com/rooms/14501505?location=Belton%2C%20TX'],
#  [42,
#   '$370',
#   '2',
#   'New Braunfels',
#   'May 2013',
#   'What a location! The Comal Hideway is nestled right on the Comal River, directly across from Schlitterbahn!   This fully-furnished unit is a home away from home! Take advantage of the community grills along the river, or relax inside with a spectacular view of the Comal!   Make your next vacation one to remember at the Comal Hideaway!',
#   29.7047139280502,
#   -98.12010313260441,
#   'Comal Hideaway! ACROSS FROM SCHLITTERBAHN!',
#   'https://www.airbnb.com/rooms/18547397?location=Comal%20River%2C%20TX'],
#  [43,
#   '$500',
#   '3',
#   'Abilene',
#   'July 2016',
#   "Perfect home for rest and relaxation. With close to 4k sq. ft. You'll feel right at home with big couches, big kitchen, and big comfy beds! Everything's bigger in Texas! You'll have full access to our outdoor patio with fire pit, outdoor shower, and two water features. The space has all been completely renovated and is ready for you to enjoy!",
#   32.436160808846395,
#   -99.7740097883848,
#   'Texas style elegance and class!',
#   'https://www.airbnb.com/rooms/18838247?location=Cisco%2C%20TX'],
#  [44,
#   '$35',
#   '1',
#   'Houston',
#   'January 2017',
#   'Clean &amp; Cozy brick home with comfortable room for a guest to rent per night, large backyard with 2 big Trees for shade.Direct TV of over 500 channels to watch. Washer/Dryer, bed sheets/pillow cases',
#   29.703897011006898,
#   -95.6639534141498,
#   'Comfortable Room available for you!',
#   'https://www.airbnb.com/rooms/16929402?location=Cinco%20Ranch%2C%20TX'],
#  [45,
#   '$85',
#   '3',
#   'Abilene',
#   'December 2015',
#   'Stylishly updated 3 bedroom house, conveniently located across the street from the Taylor County Expo Center, Shotwell Stadium, The Abilene ZOO, and Lyle Land &amp; Cattle and only minutes from the Abilene Airport.',
#   32.4378100178221,
#   -99.69983992222859,
#   'Summoner Sanctuary--Abilene Home Away From Home',
#   'https://www.airbnb.com/rooms/19286138?location=Cisco%2C%20TX'],
#  [46,
#   '$50',
#   '1',
#   'Austin',
#   'June 2017',
#   'Apartment finished to a high standard, for people who value prestige. The apartment is furnished, ready to move in.',
#   30.232940805892802,
#   -97.58937812320829,
#   'Lovely private room',
#   'https://www.airbnb.com/rooms/19209856?location=Cedar%20Creek%2C%20TX'],
#  [47,
#   '$117',
#   '2',
#   'Fort Worth',
#   'October 2014',
#   "This house will have you feeling like you're staying in the country when you're a 20-minute walk or 5-minute ride to Downtown! A bikeshare station on Samuels Ave. connects you to points of downtown including West 7th, museum district, magnolia, and the trinity trails. A train track near the house provides some ambient noise adding to a unique atmosphere. We loved while living in this house for over 8 years, renovating it for an open, connected, and modernized concept.",
#   32.7665072085702,
#   -97.3287367093026,
#   "1920's Bungalow / Craftsman near Downtown",
#   'https://www.airbnb.com/rooms/7255032?location=Colleyville%2C%20TX'],
#  [48,
#   '$244',
#   '2',
#   'Marble Falls',
#   'January 2014',
#   'Two Bedroom: King in master, two full beds in second bedroom, sleeper sofa in living area. Maximum occupancy is 8.  **See “Description” Below for ALL details**',
#   30.5511186819018,
#   -98.28646130734221,
#   'Marble Falls, TX, 2-bedroom #1',
#   'https://www.airbnb.com/rooms/14359371?location=Burnet%2C%20TX'],
#  [49,
#   '$850',
#   '3',
#   'Pasadena',
#   'August 2015',
#   'Completely renovated single family home in Pasadena, Super Bowl ready, 21 miles and 25 minutes from NRG stadium. Full access allowed. Large master suite with a king size bed and 2 additional bedrooms.',
#   29.647322509057197,
#   -95.13905354682129,
#   '25 Miles to Super Bowl, pool and spa, full access',
#   'https://www.airbnb.com/rooms/16678532?location=Beach%20City%2C%20TX'],
#  [50,
#   '$52',
#   '1',
#   'College Station',
#   'February 2016',
#   "My place is great because of how close it is to Kyle Field, the George Bush Library, Northgate and great places to eat! My apartment's tidiness, accommodations and great price will be a couple of the many reasons any person/couple will love it!",
#   30.5976927003456,
#   -96.33721105092128,
#   'VACATION RENTAL FOR JUNE AND JULY!',
#   'https://www.airbnb.com/rooms/13334742?location=College%20Station%2C%20TX'],
#  [51,
#   '$450',
#   '5',
#   'San Antonio',
#   'September 2016',
#   'Morning Star has an elegance of \\',
#   29.516052765485398,
#   -98.43504460673451,
#   'Welcome to MORNING STAR',
#   'https://www.airbnb.com/rooms/17714313?location=Cibolo%2C%20TX'],
#  [52,
#   '$300',
#   '4',
#   'Allen',
#   'May 2015',
#   'My home is in a very family oriented neighborhood with access to major highways (2 miles to 75 and 4 miles to 121); 45 minutes to DFW and Dallas Love airports and 45 minutes to downtown Dallas. Enjoy an amazing range of shopping within 10-20 minutes - Premium Outlet Mall, Stonebriar Mall and Watters Creek. Great for couples, solo adventurers, business travelers and families (with kids). NO PARTIES!',
#   33.0953349702649,
#   -96.70009475036949,
#   'Beautiful 4 Br/4 Ba Home Near Major Highways',
#   'https://www.airbnb.com/rooms/9793383?location=Celina%2C%20TX'],
#  [53,
#   '$207',
#   '2',
#   'Bandera',
#   'May 2014',
#   '2 bedroom house. Sleeps 6 total. 2 Twin Sleeper Futons in living room. First bedroom has a King bed, Walk in closet, and an electric fire place. Second bedroom has a Queen size bed. Full Kitchen with Stove, Refrigeratior/Icemaker, Microwave, Toaster, Coffeepot, Utensils, Plates, Cookware. Shower. Linens and Towels provided. Dish TV. Window AC/Heat. Downtown Bandera, TX. No Pets. No Smoking Inside Accommodation. Ferral Cats live on property and are fed.',
#   29.7170390036753,
#   -99.0821206583391,
#   'Hackberry House',
#   'https://www.airbnb.com/rooms/14471311?location=Center%20Point%2C%20TX'],
#  [54,
#   '$100',
#   '2',
#   'Humble',
#   'January 2016',
#   'My home, built in 2016, is 5 min from the airport in a quiet neighborhood. You will have the entire second story to yourself, with 2BR, couch, 70 in tv, full bed, inflatable queen mattress and bathroom. It is 15 min away from downtown and 30 min away from NRG. Minutes away from restaurants, mall, grocery store and 24 hr emergency room. Other amenities include a gym w/ treadmill and erg machine. We have a crate-trained German shepherd which will be limited to the 1st floor master and backyard.',
#   30.019379768387104,
#   -95.3081879543499,
#   'Cozy Second floor to yourself minutes from IAH',
#   'https://www.airbnb.com/rooms/16925131?location=Cleveland%2C%20TX'],
#  [55,
#   '$105',
#   '2',
#   'San Antonio',
#   'June 2017',
#   'A cozy apartment located in downtown San Antonio. This space is within walking distance to the Convention Center, Hemisfair Park, and the Alamodome. It is also located near the Southtown District, which features an array of restaurants, bars, and shops. Enjoy the close public park that has a baseball field, large playground, and picnic tables. We offer guests FREE pick up and drop-off from the San Antonio International Airport. There is also ample street parking, or use bike-share rack.',
#   29.4154295645797,
#   -98.4815961410352,
#   'Downtown Apartment located near Convention Center',
#   'https://www.airbnb.com/rooms/19065840?location=Alamo%20Heights%2C%20TX'],
#  [56,
#   '$81',
#   '3',
#   'Humble',
#   'January 2017',
#   'Entire 3 bedroom/2 full bath home in a quiet neighborhood. Third bedroom area furnished for office space for work/communication. Large driveway with private parking for 6 vehicles or RV. 5 Miles to IAH, family activities, some great restaurants. Blocks from US 59, NE Medical Center/Kingwood Medical Center. Great for couples, solo adventurers, business travelers, and families. **Mondays and Thursdays are blocked for bookings - NOTE: these nights, I can often make exceptions for extended stays.**',
#   30.000942588551997,
#   -95.25816793356572,
#   'Entire home 5 Miles From IAH Blocks from Hwy 59/69',
#   'https://www.airbnb.com/rooms/17006337?location=Cleveland%2C%20TX'],
#  [57,
#   '$40',
#   '1',
#   'Fort Worth',
#   'April 2017',
#   'Warm, Cozy house located in North of Fort Worth with family-friendly and safe environment close to shopping and restaurants. Conveniently located in Alliance/North Fort Worth, 5 minutes drive to I35, Alliance Town Center and 15 minutes drive to Fort Worth downtown.  Looking for long term single student/professional renters and no pets/smoking allowed.',
#   32.9175327861862,
#   -97.3369000113723,
#   'Warm, Cozy Private Room in North Fort Worth',
#   'https://www.airbnb.com/rooms/18359567?location=Colleyville%2C%20TX'],
#  [58,
#   '$120',
#   '3',
#   'Katy',
#   'April 2017',
#   'Bienvenidos! This gorgeous one-story home offers 3 bedrooms, 2 bathrooms and a 2-car garage. The elegant plan features a study room equipped with a sofa bed, gorgeous kitchen and great living space with TV (netflix included). It is tailored for all. We are located in Katy, TX, in close proximity to Katy Mills Shopping Mall, Houston Premium Outlets, Typhoon Water Park, energy corridor, and new hospital area. We sincerely hope you will have a wonderful and profitable stay in our dear town of Katy.',
#   29.750282282879702,
#   -95.79191394825571,
#   'Lovely Katy Home (3BR/2B) - Fantastic Location',
#   'https://www.airbnb.com/rooms/19387030?location=Cinco%20Ranch%2C%20TX'],
#  [59,
#   '$59',
#   '1',
#   'Irving',
#   'October 2015',
#   'Welcome to your happy place - a newly renovated, well lit and furnished private bedroom with bath/shower over tub and accompanying closet area. Located in the heart of Las Colinas, a great neighborhood - quiet and surrounded by the lake. Guests from all backgrounds are most welcome here. Complimentary guest parking available. Good access to the highway - 2mins away.',
#   32.8808895257126,
#   -96.94281766718659,
#   'Luxury Private Bedroom & Bath in Las Colinas',
#   'https://www.airbnb.com/rooms/18180466?location=Carrollton%2C%20TX'],
#  [60,
#   '$45',
#   '1',
#   'Manor',
#   'June 2017',
#   'Cozy place, 10 miles from downtown Austin, convenient to shopping centers, restaurants.',
#   30.3529023735145,
#   -97.5156872338966,
#   'Clara Martin Suite',
#   'https://www.airbnb.com/rooms/19475525?location=Coupland%2C%20TX'],
#  [61,
#   '$30',
#   '1',
#   'Katy',
#   'June 2016',
#   'My place is good for couples, solo adventurers, business travelers, and families (with kids).',
#   29.7554787684517,
#   -95.7889963311194,
#   'Charming private room in gated community in Katy',
#   'https://www.airbnb.com/rooms/16016475?location=Cinco%20Ranch%2C%20TX'],
#  [62,
#   '$199',
#   '3',
#   'League City',
#   'May 2013',
#   "Cozy Water View Lodge w/ Pool (3/3.5) Great sunset views of Clear Lake from every window and day views from the back with a deck overlooking the pool. Bring your kayaks, jet ski's or use our 40 ft boat slip. You’ll love our place because of the coziness, the views, the high ceilings and the kitchen. It's great for couples, solo adventurers, business travelers, families (with kids), or groups.",
#   29.5397107463303,
#   -95.0751853608604,
#   'Cozy with a Water View',
#   'https://www.airbnb.com/rooms/15732481?location=Clear%20Lake%20Shores%2C%20TX'],
#  [63,
#   '$38',
#   '1',
#   'Houston',
#   'May 2016',
#   "This spare room within a 2 bed/2 bath condo is within Houston's medical center district. It is minutes away from Hermann Park, Rice University, NRG Stadium, Houston Zoo, and of course, the medical center. The listing is a 3 minute walk from the nearest bus stop and a 15 minute walk from the nearest light rail station.   Cable, wifi, and toiletries included.",
#   29.6894518062607,
#   -95.3932525448847,
#   'Comfy, Affordable Med Center Room',
#   'https://www.airbnb.com/rooms/16946736?location=Bellaire%2C%20TX'],
#  [64,
#   '$250',
#   '3',
#   'Bryan',
#   'May 2017',
#   'Fully remodeled and furnished home centrally located on a quiet culdasec on the Bryan/College Station borderline. This home boasts of a large living room, spacious kitchen with tile counter tops, breakfast area &amp; eat in kitchen. Dining room is open to the kitchen and large enough to be a second living space. Enjoy evenings on the back porch or take a quick walk to either the Garden Acres park or Tanglewood park and splashpad. Close to shopping, restaurants, bars, and so much more.',
#   30.6404394654232,
#   -96.3380479290165,
#   'Great Home Away From Home',
#   'https://www.airbnb.com/rooms/18569309?location=College%20Station%2C%20TX'],
#  [65,
#   '$45',
#   '1',
#   'Houston',
#   'January 2017',
#   "YOU WILL LOVE IT. Safety, Convenience, Comfort, and Cost-Effective! One of the MOST affordable short-term medical housing.  This is an Updated all furnished 2 bedrooms and 2 bathrooms condo apartment with modern furnishings. Each private bedroom has it's own LOCK and bathroom in the bedroom suite so there is NO sharing with the other bedroom or another guest. Kitchen is furnished with all basic appliances, silverwares, cook wares, plates, bowls, glasses, etc.",
#   29.688898609425696,
#   -95.39527325804809,
#   'Texas Medical Center 2 BedRoom 2 BathRoom - Room 1',
#   'https://www.airbnb.com/rooms/17341645?location=Bellaire%2C%20TX'],
#  [66,
#   '$800',
#   '1',
#   'Conroe',
#   'January 2017',
#   'Beautiful quiet neighborhood right across the street from a park on a golf course. Private parking and only 45 minutes away from NRG Stadium. Perfect place to relax and unwind. Only 10 minutes away from tons of dine in and take out restaurants.',
#   30.2447257963802,
#   -95.4382270959255,
#   'Home right off of golf course',
#   'https://www.airbnb.com/rooms/16954892?location=Conroe%2C%20TX'],
#  [67,
#   '$40',
#   '1',
#   'San Antonio',
#   'May 2016',
#   'Make yourself at home in this double size bedroom suite with private entrance.    3 min from I-35. 10 min to downtown San Antonio, 15 min to the airport, 20 min to Six Flags, Sea World.',
#   29.482413842415102,
#   -98.4100152761692,
#   'Family Suite with private entrance',
#   'https://www.airbnb.com/rooms/16353972?location=Cibolo%2C%20TX'],
#  [68,
#   '$150',
#   '2',
#   'Houston',
#   'March 2017',
#   "We do not rent out the entire property, only private rooms. Registered guests can enjoy the outside pool area, large backyard, and pier, along with the saltwater pool and heated jacuzzi which can be enjoyed between 8 am and 10 pm.   Start your day with a walk/jog in this friendly neighborhood, enjoy a game of tennis or basketball, or fill it with one or more of the area's many tourist attractions or healthy lifestyle activities.",
#   29.536286005939303,
#   -95.0866965595521,
#   'PRIVATE SUITE & POOLSIDE ROOM',
#   'https://www.airbnb.com/rooms/17760693?location=Clear%20Lake%20Shores%2C%20TX'],
#  [69,
#   '$1083',
#   '4',
#   'Concan',
#   'February 2016',
#   'Little Blanco is a gorgeous vacation rental house located in Concan, Texas. It is in the beautiful 18 hole golf course in Concan. It is also on one of the highest points of the Golf Course. It has over 4342 sq. ft. of livable space for you and your guests. It has 4 bedrooms and 4 bathrooms and sleeps 28 people. It is a single level home.',
#   29.532130665492502,
#   -99.69302160886791,
#   'Little Blanco',
#   'https://www.airbnb.com/rooms/17808720?location=Concan%2C%20TX'],
#  [70,
#   '$35',
#   '1',
#   'Dallas',
#   'May 2016',
#   'Bedroom pictured has full bed, full closet w/ hangers, chiffarobe with shelving, and chest of drawers.. You will also have private access to your own TV room with a 60\\',
#   32.853293011450894,
#   -96.66028827102372,
#   'Nice family home close to 635, Garland & Mesquite',
#   'https://www.airbnb.com/rooms/19488681?location=Balch%20Springs%2C%20TX'],
#  [71,
#   '$130',
#   '1',
#   'Austin',
#   'March 2014',
#   "*Not an actual Treehouse  Welcome to my spacious 1 bedroom apartment located on the 2nd floor. Huge windows, a working fireplace, laminate hardwood floors, wifi, and a comfortable queen size bed are just a few perks this great space offers. I offer a self check-in so you are welcome to arrive anytime after the check-in time that's convenient for you.",
#   30.2303850707103,
#   -97.7658109511145,
#   'Treehouse Oasis with 2 bikes',
#   'https://www.airbnb.com/rooms/4279079?location=Colorado%20River%2C%20TX'],
#  [72,
#   '$22',
#   '1',
#   'San Antonio',
#   'April 2015',
#   "My place is close to the airport. The bed is located in the front room but is closed off from the rest of the house and people traffic. You’ll love my place because of the neighborhood and the kitchen. My place is good for solo adventurers.  Private room for rent, located in an established neighborhood with quick access to Loop 410, US 281 and IH-35. Only 5 minutes from the airport, 10 minutes to BAMC, and 15 to the UTHSCSA. It's perfect for anyone visiting for a short stay.",
#   29.5200790506943,
#   -98.45505578224069,
#   'Airport Trundle bed with shared bath',
#   'https://www.airbnb.com/rooms/13276148?location=Cibolo%2C%20TX'],
#  [73,
#   '$110',
#   '2',
#   'Canyon Lake',
#   'June 2014',
#   "Our wooded retreat is nestled among old growth oaks in the Potter's Creek area, just five minutes north of Canyon Lake. It is the perfect weekend spot to unwind, decompress, and get back to what's important in life. The scent of cedar will reinvigorate you, while the green hills and crystal clear rivers will call your name. Strategically located, you will be less than an hour away from Pedernales, Blanco, Wimberley, Fredericksburg and all they have to offer. Local Tax (Word CC) of 4% Included.",
#   29.9145653581492,
#   -98.26363154478571,
#   'Emerald Gem in The Texas Hill Country, Canyon Lake',
#   'https://www.airbnb.com/rooms/16338611?location=Canyon%20Lake%2C%20TX'],
#  [74,
#   '$31',
#   '1',
#   'Manor',
#   'April 2016',
#   'My place is close to Austin and all that it has to offer!. You’ll love my place because of the outdoor space, the neighborhood, and the comfy bed. My place is good for couples, solo adventurers, and business travelers.',
#   30.3580440831475,
#   -97.5428903397274,
#   'the Haven at Shadow Glen #2',
#   'https://www.airbnb.com/rooms/14854727?location=Coupland%2C%20TX'],
#  [75,
#   '$115',
#   '3',
#   'Spring',
#   'October 2016',
#   'Perfect for 1 week or longer stay. 3 bedrooms, the master has a private bath &amp; the others share a bath. The deck area has a very private feel to enjoy a beverage, smoke or to fellowship with one another.',
#   30.050417372472896,
#   -95.34459326466428,
#   'Perfect for 1 week or longer stay.',
#   'https://www.airbnb.com/rooms/15763855?location=Cleveland%2C%20TX'],
#  [76,
#   '$75',
#   '1',
#   'Irving',
#   'May 2016',
#   'Top floor condominium overlooking all of Las Colinas. Central to everything including major highways, restaurants, DFW/Love airport, bars, shopping, and grocery stores. Fully furnished, private bedroom and bath, with everything you might need during your stay~',
#   32.898033831496896,
#   -96.9564130569912,
#   'Great, private bedroom/bath near DFW airport',
#   'https://www.airbnb.com/rooms/13335834?location=Colleyville%2C%20TX'],
#  [77,
#   '$50',
#   '1',
#   'McKinney',
#   'October 2015',
#   'A delightful bedroom, twin bed, designer bedding, private ensuite 3 pc bath, TV in room, personal beverage center stocked for Keurig, private refrigerator, an additional roll-away bed available  Access to the outdoor space with pool &amp; deck Home is in the historic district just walking distance to the downtown square  McKinney is known for having a vibrant downtown area and If it’s any testament to the town, Money Magazine rated McKinney #1 place to live!',
#   33.1958892146982,
#   -96.6290797725223,
#   'BEAUTIFUL VICTORIAN FARMHOUSE',
#   'https://www.airbnb.com/rooms/8862814?location=Celina%2C%20TX'],
#  [78,
#   '$125',
#   '2',
#   'Conroe',
#   'January 2014',
#   'This Executive furnished apartment features a 1200 sq/ft 2 bed / 2 bath with a spacious family room. It sleeps 6 people comfortably. It includes a fully equipped kitchen with modern appliances, and everything that anybody would need to cook up a delicious meal. The pool view apartment also features dramatic nine-foot ceilings,Ceramic tile entries, Custom trim &amp; Crown moldings, Ceiling fans, Built-in Computer desks Oversized garden tubs, Expansive walk-in closets and full size washer and dryer.',
#   30.2034393736975,
#   -95.4294110348945,
#   'Gorgeous Pool View 2BDR/2Bath-Woodlands #12HP02',
#   'https://www.airbnb.com/rooms/15107195?location=Cleveland%2C%20TX'],
#  [79,
#   '$300',
#   '2',
#   'College Station',
#   'October 2016',
#   'My place is close to TAMU Campus. You’ll love my place because of the kitchen, the high ceilings, and the location. My place is good for couples, business travelers, and families (with kids).',
#   30.5872618645922,
#   -96.2951515822694,
#   'Gameday Sleepover',
#   'https://www.airbnb.com/rooms/15375359?location=College%20Station%2C%20TX'],
#  [80,
#   '$800',
#   '3',
#   'La Porte',
#   'January 2017',
#   'This house is great for multiple couples or family with kids. There is a covered patio with patio table and chairs. Two air mattress available if needed. Located 20 minutes from downtown and hobby airport. Walmart, grocery stores,restaurants and shopping centers within walking distance.',
#   29.6679832526087,
#   -95.08367585372591,
#   'SuperBowl 2017 home rental',
#   'https://www.airbnb.com/rooms/16961546?location=Beach%20City%2C%20TX'],
#  [81,
#   '$800',
#   '2',
#   'College Station',
#   'September 2016',
#   'My place is close to Parks, Kyle Field, Restaurants . You’ll love my place because of the location and the outdoors space. My place is good for couples, solo adventurers, business travelers, families (with kids), big groups, and furry friends (pets).',
#   30.6133901018266,
#   -96.30687281617571,
#   '3 Bedroom Home. (2 Private Rooms for Rental)',
#   'https://www.airbnb.com/rooms/15189493?location=College%20Station%2C%20TX'],
#  [82,
#   '$25',
#   '1',
#   'Plano',
#   'June 2017',
#   'this listing is only for females',
#   33.067470996905,
#   -96.66369280026791,
#   'very nice semi master suite, meadow view',
#   'https://www.airbnb.com/rooms/19143553?location=Celina%2C%20TX'],
#  [83,
#   '$50',
#   '1',
#   'Fort Worth',
#   'April 2017',
#   'Nice home with modern decor',
#   32.881564387892496,
#   -97.26585470195221,
#   'North Fort Worth home',
#   'https://www.airbnb.com/rooms/18586605?location=Bedford%2C%20TX'],
#  [84,
#   '$35',
#   '1',
#   'Euless',
#   'April 2016',
#   'Euless is 6 miles from DFW airport and in between Dallas and Ft Worth, close to attractions like six flags, Cowboy and Rangers stadiums and golf. Also near American Airline training center. We are a pet friendly home and charge $60 fee per week per pet it $10/day.',
#   32.8311820815929,
#   -97.10332628262908,
#   'Private room near airport',
#   'https://www.airbnb.com/rooms/12171433?location=Colleyville%2C%20TX'],
#  [85,
#   '$135',
#   '2',
#   'Austin',
#   'November 2016',
#   "If you're looking for a comfortable place in Brentwood with character then you've found it. It's a great launching pad for your Austin adventure located right in the Burnet district a stones throw to quick public transit downtown. Walk to several bars including Lala's (famous Christmas bar), Yard Bar, Pour House, or Aristocrat and several top notch restaurants: Stubb's BBQ, Bufalina Due, Barley Swine, Flyrite, or Lick!",
#   30.342859330909995,
#   -97.73598703923821,
#   'Austin Private Patio Convenient Downtown - Burnet',
#   'https://www.airbnb.com/rooms/16067140?location=Cedar%20Park%2C%20TX'],
#  [86,
#   '$35',
#   '1',
#   'Houston',
#   'January 2016',
#   "Hi! Our house is tucked away at the end of a quiet cul-de-sac and is 20 minute easy drive to Houston Intercontinental Airport. We have easy access to Kingwood's great greenbelts for walking and running. We are a busy family with two kids and three wonderful dogs, but our house is your house when you stay with us! You'll have your own private bedroom (upstairs) and a full bath (downstairs). A second private bedroom with an air mattress is available for larger parties.",
#   30.036835722653898,
#   -95.22608776661751,
#   'Comfortable Family Home near IAH',
#   'https://www.airbnb.com/rooms/14555472?location=Cleveland%2C%20TX'],
#  [87,
#   '$45',
#   '1',
#   'San Antonio',
#   'April 2016',
#   'Room for rent, Mountains view, clear space, wonderful neighborhood only 5 minutes from La Cantera area. The bathroom and game room will make you feel like home. Coffee, towels, soap, shampoo provided by host.',
#   29.706279393955104,
#   -98.63299228170142,
#   'Charming room 5 minutes La Cantera!',
#   'https://www.airbnb.com/rooms/14728853?location=Boerne%2C%20TX'],
#  [88,
#   '$275',
#   '3',
#   'Irving',
#   'June 2015',
#   'Clean, modern 2-story townhouse in Las Colinas, 3 miles away from the Byron Nelson golf tournament, and 2 miles away from DFW Airport. Our home is perfect for a large group or family. Enjoy the open floorplan and relax on the back patio.',
#   32.8641016055649,
#   -96.9989210796452,
#   'Cute 3br in Las Colinas, 3mi from Byron Nelson',
#   'https://www.airbnb.com/rooms/18349225?location=Colleyville%2C%20TX'],
#  [89,
#   '$89',
#   'Studio',
#   'Katy',
#   'February 2017',
#   'Room In the Heart of Katy! Proximity to the Energy Corridor, La Centerra, Katy Mills. ONE ROOM FOR ONE PERSON. POOL. Golf Course. Full Bathroom. Close to I10-99 Park Toll Way  NO PETS, NO SMOKING, NO DRUGS, Valid Driver License Due at Arrival. Thanks!',
#   29.7544339066183,
#   -95.7731594639303,
#   'Book Now! Room In the Heart of Katy!',
#   'https://www.airbnb.com/rooms/17448109?location=Cinco%20Ranch%2C%20TX'],
#  [90,
#   '$200',
#   '1',
#   'New Braunfels',
#   'December 2012',
#   'Modern luxury meets new-urban charm in Town Creek, where the brand-new TCTX Urban Lodge awaits just minutes from the historic downtown.',
#   29.7009088406543,
#   -98.1315609972357,
#   'the TCTX: lush pool in a secret courtyard (E ste.)',
#   'https://www.airbnb.com/rooms/15742579?location=Comal%20River%2C%20TX'],
#  [91,
#   '$750',
#   '3',
#   'Buchanan Dam',
#   'April 2017',
#   'Fun in the sun represents family values, great experiences and irreplaceable memories. Experience your private boat ramp and dock, and one of a kind hill country scenery. The refreshing water and secluded location allow you to float or swim without any disturbances.',
#   30.750224813200102,
#   -98.41572006959471,
#   'Fun in the Sun Lake House',
#   'https://www.airbnb.com/rooms/18395173?location=Buchanan%20Dam%2C%20TX'],
#  [92,
#   '$200',
#   '4',
#   'Humble',
#   'November 2014',
#   '4 Bedrooms, 1 living room, 1 study room, 3 full bathrooms, 1 half restroom, master bedroom w/ Jacuzzi, upstairs game room, backyard patio w/ table&amp;shade. Located 15 min from Houston. Quiet neighborhood. Close to Walmart, 10 min from mall, movies etc',
#   29.9295383838455,
#   -95.250962378514,
#   "2 Story Home by Bush Int'l Airport",
#   'https://www.airbnb.com/rooms/4520039?location=Channelview%2C%20TX'],
#  [93,
#   '$48',
#   '1',
#   'Baytown',
#   'October 2013',
#   'Fully furnished Studio Apartment with private entrance (above detached garage). Includes one queen sized bed and a full sized pop-up sofa bed. Fully equipped kitchen(Keurig, pans, cutlery and dishes) 42\\',
#   29.7458466093416,
#   -94.9635595289327,
#   'Home away from home: Studio Apt.',
#   'https://www.airbnb.com/rooms/16284048?location=Channelview%2C%20TX'],
#  [94,
#   '$145',
#   '1',
#   'Gary City',
#   'February 2016',
#   'Oak Haven Lakeside Cottages is a perfect \\',
#   32.0380454506125,
#   -94.45985039166719,
#   'Oak Haven Lakeside Cottages',
#   'https://www.airbnb.com/rooms/11226403?location=Center%2C%20TX'],
#  [95,
#   '$20',
#   '1',
#   'Irving',
#   'June 2016',
#   'My place is good for couples, solo adventurers, business travelers, families and groups of four. I have two rooms listed. The room comes with refrigerator and TV. We are LGBT friendly, and all cultures and religions are welcome.',
#   32.8324052560743,
#   -96.9892684269925,
#   'DFW airport cozy room',
#   'https://www.airbnb.com/rooms/13880761?location=Coppell%2C%20TX'],
#  [96,
#   '$40',
#   '1',
#   'Bryan',
#   'October 2014',
#   'My place is close to Texas A&amp;M Vet School. You’ll love my place because of the location. My and my dog are friendly and quiet. My place is great for students and researchers visiting Aggieland.',
#   30.630176298663397,
#   -96.367484430835,
#   'Cosy room close to Texas A&M Vet School',
#   'https://www.airbnb.com/rooms/13561050?location=College%20Station%2C%20TX'],
#  [97,
#   '$1000',
#   '2',
#   'Houston',
#   'February 2013',
#   'Our 2/2 townhouse is only a 9-min ride from NRG Stadium, the Medical Center, AND all of the cultural, dining, and nightlife offerings of the museum district, midtown, and downtown. Hobby Airport is a short cab ride away. Perfectly situated in a safe community it offers immediate access to the heart of H-town via 45 freeway and the 610 loop.   Enjoy access to safe parking, high speed, secure WiFi, Premium Cable, W&amp;D, and separate climate control for each individual floor.',
#   29.6979912705294,
#   -95.2989319579218,
#   'Perfect Townhome for Super Bowl LI & Beyond',
#   'https://www.airbnb.com/rooms/16892588?location=Channelview%2C%20TX'],
#  [98,
#   '$345',
#   '4',
#   'Eustace',
#   'July 2016',
#   'This exceptional 4-bedroom, 3-bathroom house will provide the ultimate lakefront getaway for your next Texas vacation. With room for 12 guests, immense home comforts, and a terrific location on Cedar Creek Lake, this outstanding home has it all!',
#   32.2271363527621,
#   -95.9940865461975,
# ...
#   'May 2017',
#   'Basic two level cabin on a private ranch with washer, toilet, shower, and twin bed. Room on second level for sleeping bags.',
#   35.0251688106638,
#   -101.854363135515,
#   'Creekwood Cabin',
#   'https://www.airbnb.com/rooms/19207852?location=Amarillo%2C%20TX'],
#  [971,
#   '$30',
#   '1',
#   'Austin',
#   'April 2017',
#   "This is a peaceful, quiet place in Southwest Austin. It's surrounded by excellent restaurants and shopping, 15 minutes from South Congress and downtown.   It's the perfect place for dogs, with a big grassy area and miles of walking trails right behind the building. The pool area is always clean and quiet.  The inside is simple, clean and comfortable with great natural light. The living room is cozy with free Wifi and access to Xbox and Netflix.    I'd love for you to stay here!",
#   30.212416559857804,
#   -97.81700026405649,
#   'Peaceful, Private Condo in Southwest Austin',
#   'https://www.airbnb.com/rooms/18528747?location=Austin%2C%20TX'],
#  [972,
#   '$131',
#   '2',
#   'Alpine',
#   'July 2015',
#   "Our home is rustic and Mexican style inspired. it's casual and very comfortable. It is located at the foot of the \\",
#   30.353355936350003,
#   -103.66348450386299,
#   'Relaxing home with bar & pool table',
#   'https://www.airbnb.com/rooms/17255243?location=Alpine%2C%20TX'],
#  [973,
#   '$600',
#   '4',
#   'Colleyville',
#   'June 2016',
#   'Our place is close to sports stadiums, COWBOYS restaurants , shopping, and centrally located 20 minutes to Dallas and Ft. Worth. You’ll love our home because of the amenities, location, and beautiful walking trails. On weekends there is an old western style bank robbery hold up by the railroad tracks located 1 minute from the house. Great space for family reunions or a relaxing vacation. The house has a 1,400 sq.ft patio with spectacular outdoor kitchen area by the large waterfall pool.',
#   32.8969955807587,
#   -97.17519474542108,
#   'OUR FAMILY RESORT',
#   'https://www.airbnb.com/rooms/13567426?location=Colleyville%2C%20TX'],
#  [974,
#   '$53',
#   '1',
#   'Spring',
#   'January 2016',
#   'Located conveniently for everything in the woodlands Including the Woodlands Pavilion. We have 1 bedroom for a guest. There is street parking, kitchen access, a bathroom, laundry. A park with bike and walking trails nearby. Also two dogs who love to snuggle :)',
#   30.130380268821998,
#   -95.408284673192,
#   'Boho chic bedroom',
#   'https://www.airbnb.com/rooms/10409261?location=Cleveland%2C%20TX'],
#  [975,
#   '$525',
#   '3',
#   'Smithville',
#   'November 2016',
#   "The 'Rocking M Ranch' (RMR). The property is a large, rambling duplex conveniently located less than one hour from Austin and less than two hours from Houston and San Antonio. The 'Lone Star', the largest of the two homes, is the rental and offers visitors ample privacy with sole use of the pool area. The owner occupies the smaller second home. Though new to Airbnb, RMR has been a successful rental since 2012. For property reviews, visit We are... 'Real Country, Real Close'!",
#   29.939216158675798,
#   -97.19376915852509,
#   'Secluded Home on 15 acres',
#   'https://www.airbnb.com/rooms/16163603?location=Bastrop%20County%2C%20TX'],
#  [976,
#   '$100',
#   '1',
#   'Boerne',
#   'August 2014',
#   'I have a large bedroom Suite. Private entrance, Private bath , patio, beautiful pool overlooking the gorgeous hill country for (URL HIDDEN) Fridge, coffeemaker in room, internet in room and at pool. Clothing optional poolside. Resort style property',
#   29.865013898512,
#   -98.76931788638191,
#   'Stunning Hill Country Estate',
#   'https://www.airbnb.com/rooms/3987617?location=Boerne%2C%20TX'],
#  [977,
#   '$130',
#   '1',
#   'Early',
#   'September 2014',
#   'Welcome! #2 - Villa #2one bedroom/one bath villa - all bills paid, furnished, perfect place for one or two people, queen size bed, large couch, small fridge, microwave, hot plate, toaster oven, huge tile shower, free WiFi, and Direct TV. As host who own and live on the property, we try to be welcoming and responsive. We will also respect your privacy and never intrude, either your space or your time. Enjoy the unique 3-Plex Villas.',
#   31.755312490769,
#   -98.9127321516371,
#   'Upscale 3-plex Extended Stay #2 Villa Apartment',
#   'https://www.airbnb.com/rooms/4132832?location=Cisco%2C%20TX'],
#  [978,
#   '$245',
#   '3',
#   'Horseshoe Bay',
#   'February 2016',
#   '*Dynamic Inventory* - INQUIRE FIRST-  *There maybe a cleaning fee of $100 if the booking request is for 5 days or less.*  Three Bedroom: King in master, two full beds in second bedroom, king in third bedroom, sleeper sofa in living area. Maximum occupancy is 10.  High season rates are higher than whats listed on the calendar;  Weekends : $360/night Weekday : $300/night  The current rate on the calendar will be valid if the booking request is within 5 days of arrival.',
#   30.550795369877,
#   -98.28505076874642,
#   'Marble Falls - 3BR',
#   'https://www.airbnb.com/rooms/17760247?location=Bertram%2C%20TX'],
#  [979,
#   '$98',
#   '3',
#   'San Antonio',
#   'February 2013',
#   'Memorial Holiday is almost upon us. Here is to a wonderful 2017 in San Antonio!!  The Texas Blue Bell is a 2012 stucco two story home in the beautiful, quiet Summerwood private community. This spectacular location is right next door to the nationally recognized Medical Center of San Antonio.   We look forward to your visit.',
#   29.5008244916758,
#   -98.5962632852755,
#   'Texas Blue Bell in Medical Center',
#   'https://www.airbnb.com/rooms/16758012?location=Bulverde%2C%20TX'],
#  [980,
#   '$391',
#   '2',
#   'Corpus Christi',
#   'December 2015',
#   'Village by the Beach I912 is first class living on the Texas Gulf Coast - Come stay and enjoy one of the luxurious Village by the Beach rental properties.',
#   27.6092541279925,
#   -97.20925053169658,
#   'Village by the Beach I912',
#   'https://www.airbnb.com/rooms/13806361?location=Baffin%20Bay%2C%20TX'],
#  [981,
#   '$27',
#   '1',
#   'Arlington',
#   'March 2017',
#   'My place is is good for couples, solo adventurers, and business travelers and also close to  AT&amp;T Stadium- 6 min drive Six Flags Amusement Park- 10 min drive Six Flags Hurricane Harbor Waterpark- 10 min drive DFW Airport-20 min drive',
#   32.754284046887,
#   -97.1069299793358,
#   'Cozy Comfy Apt Close to Everywhere + Free Parking',
#   'https://www.airbnb.com/rooms/17574721?location=Arlington%2C%20TX'],
#  [982,
#   '$500',
#   '2',
#   'Dallas',
#   'January 2015',
#   "Perfect 2 bed 2 bath by Top Golf, Lake and the best mall in Dallas North Park! Memory foam bedding and large bathrooms. Very well appointed and luxurious. Search no more you've found the perfect place!",
#   32.873596161985,
#   -96.81113384432959,
#   'Luxury Holiday Home in ❤of Dallas',
#   'https://www.airbnb.com/rooms/15397663?location=Addison%2C%20TX'],
#  [983,
#   '$349',
#   '3',
#   'Corpus Christi',
#   'February 2016',
#   '*No hidden fees. All utilities included. *Roomy, very clean 3 bedroom/3 bath town home w/ Master down *2 reserved parking spots at door.  * Resort pool with grills, picnic tables &amp; play area.  * Close to beaches &amp; Schlitterbahn.  * National Seashore, Corpus Christi, Rockport, Port Aransas a short drive away.  * Boating, fishing, eateries, museums, shopping, concert halls, award winning Aquarium, AA baseball, sightseeing, horseback riding on the beach!',
#   27.606259201356696,
#   -97.2232192235298,
#   'Gull Cottage -1 Mile To Beach - LocalTax Included',
#   'https://www.airbnb.com/rooms/14490074?location=Aransas%20Pass%2C%20TX'],
#  [984,
#   '$37',
#   '1',
#   'Plano',
#   'March 2016',
#   '- Furniture in the bedroom was purchased in Oct 2016 - Bed sheets are washed before new guests arrive - Clean towels provided daily - Bathroom is frequently cleaned - DFW Airport is 26mi and Love Field Airport is 22mi away - Large table in separate room for dinning or working - Jack and Jill bathroom - High speed wifi internet - Free coffee (Keurig)  - Home is in safe neighborhood with security system',
#   33.0176951755938,
#   -96.75652289556808,
#   'Simmons Beautyrest King Bed',
#   'https://www.airbnb.com/rooms/15469567?location=Allen%2C%20TX'],
#  [985,
#   '$175',
#   '3',
#   'Point Venture',
#   'May 2015',
#   'The lake is full! Enjoy lakeviews! Point Venture in this Silverton Custom Home built in 2004. There is plenty to do from the enjoying the clear blue water of Lake Travis at the PV park, PV pool, the golf course or tennis on one of six courts.',
#   30.381027205177602,
#   -97.9974862966139,
#   'Kamp King Lakeview of Lake Travis',
#   'https://www.airbnb.com/rooms/6290179?location=Bee%20Cave%2C%20TX'],
#  [986,
#   '$36',
#   '1',
#   'Austin',
#   'March 2016',
#   'My place is close to parks, public transport, moon tower saloon, strange brew, farmers market on sat. morning. You’ll love my place because of the comfy bed (queen organic cotton w/ tempur-pedic topper), the ambiance, the outdoor space, non toxic indoor air. My place is good for solo adventurers and business travelers.',
#   30.1829391643117,
#   -97.8014689593101,
#   'You can have the red room',
#   'https://www.airbnb.com/rooms/13361970?location=Austin%2C%20TX'],
#  [987,
#   '$26',
#   '1',
#   'Denton',
#   'November 2014',
#   'VERY IMPORTANT that you know before booking that this is NOT a room. This listing is for a private and quiet pad site to park your RV or camper with connections for water, sewer, &amp; 50 or 20 amp service(see pictures). There is no access to the main house.  Less than 2 miles to Denton downtown square. Nearby shopping, restaurants, &amp; a lovely public park. Very close to UNT, Apogee stadium, &amp; Interstate 35.',
#   33.223703994966,
#   -97.15519380069959,
#   'Private RV & Camper Site Near Downtown Denton',
#   'https://www.airbnb.com/rooms/15257801?location=Corinth%2C%20TX'],
#  [988,
#   '$32',
#   '1',
#   'Manor',
#   'February 2016',
#   'Guest Room and Closet with Private 4 piece bathroom, Washer/Dryer, Full Kitchen, Large Backyard, Quite Neighborhood, Street Parking.  20 Minutes from Airport 25 Minutes From Down-Town Austin (SXSW Venues)  Owner lives onsite.',
#   30.318644624917198,
#   -97.5357625803453,
#   'One Room & Private Bathroom',
#   'https://www.airbnb.com/rooms/11509089?location=Coupland%2C%20TX'],
#  [989,
#   '$115',
#   '3',
#   'Universal City',
#   'March 2013',
#   "A 2 story Cozy Coventry-Styled home nestled in a cul-de-sac in an upscale neighborhood walking distance to the Olympia Golf Course! Universal City ( only 15 minutes to San Antonio International Airport) is the Gateway to Randolph Air Force Base. It's minutes to Retama Park (a horse racing track).",
#   29.5592261971029,
#   -98.31159311285509,
#   'The Randolph Aviator PIT Pad',
#   'https://www.airbnb.com/rooms/6977015?location=Converse%2C%20TX'],
#  [990,
#   '$900',
#   '3',
#   'Austin',
#   'October 2013',
#   'Brand new fully furnished home located minutes from the track. Spacious 3 bedroom and 2.5 bath. Sleeps 8 comfortably. Large open living room and kitchen. Outside deck with gas grill. Kegerator also included. ',
#   30.168573534310497,
#   -97.6125990774629,
#   '5 miles from Formula 1 Track',
#   'https://www.airbnb.com/rooms/1809983?location=Bastrop%20County%2C%20TX'],
#  [991,
#   '$65',
#   '1',
#   'Arlington',
#   'June 2016',
#   'My place is close to AT&amp;T Stadium, Texas Rangers Stadium, Six-Flags, DFW Airport, Love Field Airport, The Highlands Shopping Mall.. You’ll love my place because it is situated between Dallas and Ft Worth, is very clean and cozy, and you will have it all to yourself. My place is good for couples, solo adventurers, and business travelers.',
#   32.6949324072419,
#   -97.0655116930428,
#   'Arlington Apartment near Cowboys Stadium',
#   'https://www.airbnb.com/rooms/13397017?location=Arlington%2C%20TX'],
#  [992,
#   '$295',
#   '3',
#   'Austin',
#   'September 2012',
#   'Large, affordable 3/2 condo - a short walk to great restaurants, 4 bar districts, shopping, mass transit, The convention center, music venues, hike and bike trails, and all the major downtown hotels. Perfect for business travelers or just a leisure visit to Austin. : See full description below; concierge service available)',
#   30.265865937180802,
#   -97.7399196797612,
#   'Perfect 4 Executives/Professionals',
#   'https://www.airbnb.com/rooms/690984?location=Colorado%20River%2C%20TX'],
#  [993,
#   '$25',
#   '1',
#   'Katy',
#   'May 2017',
#   'Cozy clean space in a beautiful house, set in a serene neighborhood.',
#   29.8230015744983,
#   -95.7777932056225,
#   "Joshua's Place III",
#   'https://www.airbnb.com/rooms/18763755?location=Cinco%20Ranch%2C%20TX'],
#  [994,
#   '$190',
#   '1',
#   'New Ulm',
#   'February 2011',
#   'This cabin is surrounded by woods and wildlife. It faces a spring-fed pond, on 59 acres of woodland trails. Perfect in every season, the cabin offers luxury in serene surroundings where donkeys, horse, longhorns, &amp; oreo boy wonder by: transforming!',
#   29.896086491924702,
#   -96.5038315367085,
#   'Lily Ponds Cottage, natural wonder!',
#   'https://www.airbnb.com/rooms/72003?location=Columbus%2C%20TX'],
#  [995,
#   '$75',
#   '1',
#   'Benbrook',
#   'June 2016',
#   'We are minutes from Fort Worth cultural district, fine and casual dining, bike, hike trails and shopping. Family- friendly activities: walking and bike trails, swimming, bowling, laser tag, cultural district, stock yards, zoo, museums and much more. Nightlife includes: finest eateries, piano bars, music (Bass Hall productions), and dancing ( Billy Bobs) in the South!',
#   32.7058607262927,
#   -97.41937585966092,
#   "R&P's Southern Comfort",
#   'https://www.airbnb.com/rooms/13575369?location=Burleson%2C%20TX'],
#  [996,
#   '$325',
#   '1',
#   'Pflugerville',
#   'November 2016',
#   'We made our home special by creating a beautiful sanctuary with our own decorating style. We have an open are concept home. Our kitchen is fully equipped with anything you would need to create a beautiful dinner for your significant other or family. Our rooms are extremely large and we have provided toiletries for the bathrooms and bowls and beds for the dogs. We have a large backyard where you can grill for family and friends. This is our loving property.',
#   30.4530787416693,
#   -97.5888799609768,
#   'Beautiful & Quiet Pflugerville Home',
#   'https://www.airbnb.com/rooms/16918523?location=Coupland%2C%20TX'],
#  [997,
#   '$30',
#   '2',
#   'Kemah',
#   'January 2017',
#   'Upstairs suite includes 2 huge bedrooms and family room with Marina view located close to Kemah Boardwalk for family fun. Comfortable 5 bedroom 3.5 bath home, 5 minutes from Kemah Boardwark; 30 minutes from NRG Stadium and Superbowl Action. Easy access to Galveston Beaches; NASA space Center an and more. Featuring a Pool.',
#   29.5483692801028,
#   -95.0555964115114,
#   'Superbowl-Kemah Holiday',
#   'https://www.airbnb.com/rooms/16579693?location=Bacliff%2C%20TX'],
#  [998,
#   '$40',
#   '1',
#   'Temple',
#   'February 2014',
#   'This home is available for entire home rental(if conducive to our schedule however), or a partial room rental to medical/health care professionals as needed. Very close to VA and S&amp;W. if wanted to move into our home and lease yearly , rate is $1,800 monthly.Futon room also ok',
#   31.041166924179898,
#   -97.3713336453168,
#   'a Warm&Relaxed private bedroom',
#   'https://www.airbnb.com/rooms/12683393?location=Belton%2C%20TX'],
#  [999,
#   '$33',
#   '1',
#   'Austin',
#   'June 2013',
#   'Every corner of Austin is within easy reach. Our place is great for people moving to town who want get a feel before they rent or buy. We are totally a smoke-free home.',
#   30.3466252096099,
#   -97.68895937888,
#   'Quiet landing pad for new arrivals',
#   'https://www.airbnb.com/rooms/13605921?location=Coupland%2C%20TX'],
#  [1000,
#   '$140',
#   '1',
#   'Houston',
#   'January 2017',
#   "**Will give discount to previous guests :)  Here to present you a peaceful home with a gorgeous view and relaxation in Downtown! Chill and Scenic all for you! Can't wait to host and meet you! One block away from metro that rides down Main St. Walking distance to many restaurants, shopping areas, Toyota Stadium, Discovery Green, and more.",
#   29.7505525639324,
#   -95.367002700051,
#   'Downtown Hi Rise with AMAZING VIEW',
#   'https://www.airbnb.com/rooms/16913815?location=Alvin%2C%20TX'],
#  ...]

# %%
for i in df1:
    i.remove(i[0])

# %%
s=pd.isnull(df1).sum()

# %%
s
# Out:
# 104

# %%
nltk.download("stopwords")
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/milpro/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
stopwords = stopwords.words('english') # get english stop words

# %%
tokenizer = RegexpTokenizer("[\w'\$]+")

# %%
st = PorterStemmer()

# %%
df.description = df.description.apply(str).apply(tokenizer.tokenize)

# %%
df.title = df.title.apply(str).apply(tokenizer.tokenize)

# %%
df.description = df.description.apply(lambda x : [item for item in x if item not in stopwords])

# %%
df.title = df.title.apply(lambda x : [item for item in x if item not in stopwords])

# %%
df.description = df.description.apply(lambda x : [st.stem(y) for y in x])

# %%
df.title = df.title.apply(lambda x : [st.stem(y) for y in x])

# %%
df.head()
# Out:
#    Unnamed: 0 average_rate_per_night bedrooms_count         city  \
# 0           1                    $27              2       Humble
# 1           2                   $149              4  San Antonio
# 2           3                    $59              1      Houston
# 3           4                    $60              1        Bryan
# 4           5                    $75              2   Fort Worth
#
#   date_of_listing                                        description  \
# 0        May 2016  [welcom, stay, privat, room, queen, bed, detac...
# 1   November 2010  [stylish, fulli, remodel, home, upscal, NW, al...
# 2    January 2017  ['river, hous, island, close, city', A, well, ...
# 3   February 2016  [privat, bedroom, cute, littl, home, situat, c...
# 4   February 2017  [welcom, origin, 1920', home, We, recent, purc...
#
#     latitude  longitude                                             title  \
# 0  30.020138 -95.293996  [2, privat, room, bathroom, 10min, iah, airport]
# 1  29.503068 -98.447688     [uniqu, locat, alamo, height, design, inspir]
# 2  29.829352 -95.081549                         [river, hous, near, citi]
# 3  30.637304 -96.337846                      [privat, room, close, campu]
# 4  32.747097 -97.286434                                      [the, porch]
#
#                                                  url
# 0  https://www.airbnb.com/rooms/18520444?location...
# 1  https://www.airbnb.com/rooms/17481455?location...
# 2  https://www.airbnb.com/rooms/16926307?location...
# 3  https://www.airbnb.com/rooms/11839729?location...
# 4  https://www.airbnb.com/rooms/17325114?location...
